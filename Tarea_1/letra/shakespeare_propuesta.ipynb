# %% [markdown]
# # Introducción a la Ciencia de Datos: Tarea 1
#
# Este notebook contiene el código de base para realizar la Tarea 1 del curso. Puede copiarlo en su propio repositorio y trabajar sobre el mismo.
# Las **instrucciones para ejecutar el notebook** están en la [página inicial del repositorio](https://github.com/DonBraulio/introCD).
#
# Se utiliza el lenguaje Python y la librería Pandas. Si no tiene ninguna familiaridad con la librería, se recomienda realizar algún tutorial introductorio (ver debajo).
# También se espera que los alumnos sean proactivos a la hora de consultar las documentaciones de las librerías y del lenguaje, para entender el código provisto.
# Además de los recursos provistos en la [página del curso](https://eva.fing.edu.uy/course/view.php?id=1378&section=1), los siguientes recursos le pueden resultar interesantes:
#  - [Pandas getting started](https://pandas.pydata.org/docs/getting_started/index.html#getting-started) y [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html): Son parte de la documentación en la página oficial de Pandas.
#  - [Kaggle Learn](https://www.kaggle.com/learn): Incluye tutoriales de Python y Pandas.
#
#
# Si desea utilizar el lenguaje R y está dispuesto a no utilizar (o traducir) este código de base, también puede hacerlo.
#
# En cualquier caso, **se espera que no sea necesario revisar el código para corregir la tarea**, ya que todos los resultados y análisis relevantes deberían estar en el **informe en formato PDF**.

# %% [markdown]
# ## Cargar bibliotecas (dependencias)
# Recuerde instalar los requerimientos (`requirements.txt`) en el mismo entorno donde está ejecutando este notebook (ver [README](https://github.com/DonBraulio/introCD)).

# %%
from time import time
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %% [markdown]
# ## Conexión a la Base y Lectura de Datos

# %%
# Creamos el directorio Tarea_1/data/shakespeare
data_dir = Path("data") / "shakespeare"
data_dir.mkdir(parents=True, exist_ok=True)


def load_table(table_name, engine):
    """
    Leer la tabla con SQL y guardarla como CSV,
    o cargarla desde el CSV si ya existe
    """
    path_table = data_dir / f"{table_name}.csv"
    if not path_table.exists():
        print(f"Consultando tabla con SQL: {table_name}")
        t0 = time()
        df_table = pd.read_sql(f"SELECT * FROM {table_name}", engine)
        t1 = time()
        print(f"Tiempo: {t1 - t0:.1f} segundos")

        print(f"Guardando: {path_table}\n")
        df_table.to_csv(path_table)
    else:
        print(f"Cargando tabla desde CSV: {path_table}")
        df_table = pd.read_csv(path_table, index_col=[0])
    return df_table


print("Conectando a la base...")
conn_str = "mysql+pymysql://guest:relational@db.relational-data.org:3306/Shakespeare"
engine = create_engine(conn_str)

table_lst = ["works","paragraphs","chapters","characters"]
table_dic = {}

for table_name in table_lst:
    table_dic[table_name] = load_table(table_name, engine)
    
# DataFrame con todas las obras:
##df_works = load_table("works", engine)

# Todos los párrafos de todas las obras
##df_paragraphs = load_table("paragraphs", engine)

# TODO: cargar el resto de las tablas
# Out:
# Conectando a la base...
# Cargando tabla desde CSV: data/shakespeare/works.csv
# Cargando tabla desde CSV: data/shakespeare/paragraphs.csv
# Cargando tabla desde CSV: data/shakespeare/chapters.csv
# Cargando tabla desde CSV: data/shakespeare/characters.csv

# %% [markdown]
# ## Exploración de Datos

# %%
# Veamos las obras incluídas:
table_dic["works"]
# Out:
#     id                      Title                                  LongTitle  \
# 0    1              Twelfth Night            Twelfth Night, Or What You Will
# 1    2  All's Well That Ends Well                  All's Well That Ends Well
# 2    3       Antony and Cleopatra                       Antony and Cleopatra
# 3    4             As You Like It                             As You Like It
# 4    5           Comedy of Errors                       The Comedy of Errors
# 5    6                 Coriolanus                                 Coriolanus
# 6    7                  Cymbeline                 Cymbeline, King of Britain
# 7    8                     Hamlet  Tragedy of Hamlet, Prince of Denmark, The
# 8    9           Henry IV, Part I                History of Henry IV, Part I
# 9   10          Henry IV, Part II               History of Henry IV, Part II
# 10  11                    Henry V                         History of Henry V
# 11  12           Henry VI, Part I                History of Henry VI, Part I
# 12  13          Henry VI, Part II               History of Henry VI, Part II
# 13  14         Henry VI, Part III              History of Henry VI, Part III
# 14  15                 Henry VIII                      History of Henry VIII
# 15  16              Julius Caesar               The Tragedy of Julius Caesar
# 16  17                  King John                       History of King John
# 17  18                  King Lear                   The Tragedy of King Lear
# 18  19          Lover's Complaint                        A Lover's Complaint
# 19  20       Love's Labour's Lost                       Love's Labour's Lost
# 20  21                    Macbeth                     The Tragedy of Macbeth
# 21  22        Measure for Measure                        Measure for Measure
# 22  23         Merchant of Venice                    Merchant of Venice, The
# 23  24     Merry Wives of Windsor                Merry Wives of Windsor, The
# 24  25    Midsummer Night's Dream                  A Midsummer Night's Dream
# 25  26     Much Ado about Nothing                     Much Ado about Nothing
# 26  27                    Othello     The Tragedy of Othello, Moor of Venice
# 27  28         Passionate Pilgrim                     The Passionate Pilgrim
# 28  29                   Pericles                   Pericles, Prince of Tyre
# 29  30     Phoenix and the Turtle                 The Phoenix and the Turtle
# 30  31            Rape of Lucrece                        The Rape of Lucrece
# 31  32                 Richard II                      History of Richard II
# 32  33                Richard III                     History of Richard III
# 33  34           Romeo and Juliet            The Tragedy of Romeo and Juliet
# 34  35                    Sonnets                                    Sonnets
# 35  36        Taming of the Shrew                    The Taming of the Shrew
# 36  37                    Tempest                                The Tempest
# 37  38            Timon of Athens             The Tragedy of Timon of Athens
# 38  39           Titus Andronicus                           Titus Andronicus
# 39  40       Troilus and Cressida                       Troilus and Cressida
# 40  41    Two Gentlemen of Verona                    Two Gentlemen of Verona
# 41  42           Venus and Adonis                           Venus and Adonis
# 42  43          The Winter's Tale                          The Winter's Tale
#
#     Date GenreType
# 0   1599    Comedy
# 1   1602    Comedy
# 2   1606   Tragedy
# 3   1599    Comedy
# 4   1589    Comedy
# 5   1607   Tragedy
# 6   1609   History
# 7   1600   Tragedy
# 8   1597   History
# 9   1597   History
# 10  1598   History
# 11  1591   History
# 12  1590   History
# 13  1590   History
# 14  1612   History
# 15  1599   Tragedy
# 16  1596   History
# 17  1605   Tragedy
# 18  1609      Poem
# 19  1594    Comedy
# 20  1605   Tragedy
# 21  1604    Comedy
# 22  1596    Comedy
# 23  1600    Comedy
# 24  1595    Comedy
# 25  1598    Comedy
# 26  1604   Tragedy
# 27  1598      Poem
# 28  1608   History
# 29  1601      Poem
# 30  1594      Poem
# 31  1595   History
# 32  1592   History
# 33  1594   Tragedy
# 34  1609    Sonnet
# 35  1593    Comedy
# 36  1611    Comedy
# 37  1607   Tragedy
# 38  1593   Tragedy
# 39  1601   Tragedy
# 40  1594    Comedy
# 41  1593      Poem
# 42  1610    Comedy

# %%
table_dic["paragraphs"]["PlainText"]
# Out:
# 0        [Enter DUKE ORSINO, CURIO, and other Lords; Mu...
# 1        If music be the food of love, play on;\nGive m...
# 2                               Will you go hunt, my lord?
# 3                                             What, Curio?
# 4                                                The hart.
#                                ...
# 35460    That she is living,\nWere it but told you, sho...
# 35461    You gods, look down\nAnd from your sacred vial...
# 35462    There's time enough for that;\nLest they desir...
# 35463    O, peace, Paulina!\nThou shouldst a husband ta...
# 35464                                             [Exeunt]
# Name: PlainText, Length: 35465, dtype: object

# %% [markdown]
# ## Limpieza de Texto y Conteo de Palabras

# %%
import string

# Modifique la funcion para evitar el loop y usar "str.maketrans" 
# y los signos de puntuacion por defecto definidos por python en "string.punctuation"
def clean_text(df, column_name):
  """
  Reemplaza los signos de puntuación por espacios en blanco usando str.translate
  """
  # Convertir todo a minúsculas
  result = df[column_name].str.lower()

  # Crear tabla de traducción
  translation_table = str.maketrans(dict.fromkeys(string.punctuation, " "))

  # Aplicar la traducción
  return result.str.translate(translation_table)

df_paragraphs = table_dic["paragraphs"]

# Creamos una nueva columna CleanText a partir de PlainText
df_paragraphs["CleanText"] = clean_text(df_paragraphs, "PlainText")

# Veamos la diferencia
df_paragraphs[["PlainText", "CleanText"]]
# Out:
#                                                PlainText  \
# 0      [Enter DUKE ORSINO, CURIO, and other Lords; Mu...
# 1      If music be the food of love, play on;\nGive m...
# 2                             Will you go hunt, my lord?
# 3                                           What, Curio?
# 4                                              The hart.
# ...                                                  ...
# 35460  That she is living,\nWere it but told you, sho...
# 35461  You gods, look down\nAnd from your sacred vial...
# 35462  There's time enough for that;\nLest they desir...
# 35463  O, peace, Paulina!\nThou shouldst a husband ta...
# 35464                                           [Exeunt]
#
#                                                CleanText
# 0       enter duke orsino  curio  and other lords  mu...
# 1      if music be the food of love  play on \ngive m...
# 2                             will you go hunt  my lord
# 3                                           what  curio
# 4                                              the hart
# ...                                                  ...
# 35460  that she is living \nwere it but told you  sho...
# 35461  you gods  look down\nand from your sacred vial...
# 35462  there s time enough for that \nlest they desir...
# 35463  o  peace  paulina \nthou shouldst a husband ta...
# 35464                                            exeunt
#
# [35465 rows x 2 columns]

# %%
# Convierte párrafos en listas "palabra1 palabra2 palabra3" -> ["palabra1", "palabra2", "palabra3"]
df_paragraphs["WordList"] = df_paragraphs["CleanText"].str.split()

# Veamos la nueva columna creada
# Notar que a la derecha tenemos una lista: [palabra1, palabra2, palabra3]
df_paragraphs[["CleanText", "WordList"]]
# Out:
#                                                CleanText  \
# 0       enter duke orsino  curio  and other lords  mu...
# 1      if music be the food of love  play on \ngive m...
# 2                             will you go hunt  my lord
# 3                                           what  curio
# 4                                              the hart
# ...                                                  ...
# 35460  that she is living \nwere it but told you  sho...
# 35461  you gods  look down\nand from your sacred vial...
# 35462  there s time enough for that \nlest they desir...
# 35463  o  peace  paulina \nthou shouldst a husband ta...
# 35464                                            exeunt
#
#                                                 WordList
# 0      [enter, duke, orsino, curio, and, other, lords...
# 1      [if, music, be, the, food, of, love, play, on,...
# 2                        [will, you, go, hunt, my, lord]
# 3                                          [what, curio]
# 4                                            [the, hart]
# ...                                                  ...
# 35460  [that, she, is, living, were, it, but, told, y...
# 35461  [you, gods, look, down, and, from, your, sacre...
# 35462  [there, s, time, enough, for, that, lest, they...
# 35463  [o, peace, paulina, thou, shouldst, a, husband...
# 35464                                           [exeunt]
#
# [35465 rows x 2 columns]

# %%
# Nuevo dataframe: cada fila ya no es un párrafo, sino una sóla palabra
df_words = df_paragraphs.explode("WordList")

# Quitamos estas columnas redundantes
df_words.drop(columns=["CleanText", "PlainText"], inplace=True)

# Renombramos la columna WordList -> word
df_words.rename(columns={"WordList": "word"}, inplace=True)

# Verificar que el número de filas es mucho mayor
df_words
# Out:
#            id  ParagraphNum  character_id  chapter_id     word
# 0      630863             3          1261       18704    enter
# 0      630863             3          1261       18704     duke
# 0      630863             3          1261       18704   orsino
# 0      630863             3          1261       18704    curio
# 0      630863             3          1261       18704      and
# ...       ...           ...           ...         ...      ...
# 35463  666326          3483           667       19648        d
# 35463  666326          3483           667       19648  hastily
# 35463  666326          3483           667       19648     lead
# 35463  666326          3483           667       19648     away
# 35464  666327          3504          1261       19648   exeunt
#
# [909359 rows x 5 columns]

# %% [markdown]
#  ## Personajes con mayor cantidad de palabras

# %%
# Agregamos el nombre de los personajes
# TODO: des-comentar luego de cargar df_characters
df_characters = table_dic["characters"]
df_words = pd.merge(df_words, df_characters[["id", "CharName"]], left_on="character_id", right_on="id")

# %%
# TODO:
# - des-comentar luego de hacer el merge
# - Encuentra algún problema en los resultados?

words_per_character = df_words.groupby("CharName")["word"].count().sort_values(ascending=False)
words_per_character
# Out:
# CharName
# Poet                  50762
# (stage directions)    16443
# Henry V               15428
# Falstaff              14906
# Hamlet                12291
#                       ...
# Philip                    3
# Nicholas                  2
# Joseph                    2
# Taurus                    2
# Thieves                   1
# Name: word, Length: 925, dtype: int64

# %%
personajes_a_eliminar = ['(stage directions)']
personajes_filtrados = words_per_character.index[~words_per_character.index.isin(personajes_a_eliminar)]
words_per_character_filtrado = words_per_character[personajes_filtrados]

# %%
# Ejemplo: 10 personajes con más palabras
char_show = words_per_character_filtrado[:10]
plt.bar(char_show.index, char_show.values)
_ = plt.xticks(rotation=90)

# %%
characters_filtered = df_characters[df_characters['Description'].isna()]
print(characters_filtered.to_string())
# Out:
#         id                               CharName                  Abbrev Description
# 0        1                       First Apparition        First Apparition         NaN
# 1        2                          First Citizen           First Citizen         NaN
# 2        3                      First Conspirator       First Conspirator         NaN
# 3        4                        First Gentleman         First Gentleman         NaN
# 4        5                             First Goth              First Goth         NaN
# 5        6                         First Murderer          First Murderer         NaN
# 6        7                         First Musician          First Musician         NaN
# 7        8                         First Musician          First Musician         NaN
# 8        9                          First Officer           First Officer         NaN
# 9       10                           First Player                   1Play         NaN
# 10      11                          First Senator           First Senator         NaN
# 12      13                          First Servant           First Servant         NaN
# 13      14                      First Serving-Man       First Serving-Man         NaN
# 14      15                          First Soldier           First Soldier         NaN
# 15      16                         First Watchman          First Watchman         NaN
# 16      17                         First Watchman          First Watchman         NaN
# 17      18                            First Witch             First Witch         NaN
# 18      19                      Second Apparition       Second Apparition         NaN
# 19      20                     Second Conspirator      Second Conspirator         NaN
# 20      21                       Second Gentleman        Second Gentleman         NaN
# 21      22                            Second Goth             Second Goth         NaN
# 22      23                        Second Murderer         Second Murderer         NaN
# 23      24                        Second Musician         Second Musician         NaN
# 24      25                       Second Patrician        Second Patrician         NaN
# 25      26                         Second Senator          Second Senator         NaN
# 27      28                         Second Servant          Second Servant         NaN
# 28      29                     Second Serving-Man      Second Serving-Man         NaN
# 29      30                         Second Soldier          Second Soldier         NaN
# 30      31                        Second Watchman         Second Watchman         NaN
# 31      32                        Second Watchman         Second Watchman         NaN
# 32      33                           Second Witch            Second Witch         NaN
# 33      34                       Third Apparition        Third Apparition         NaN
# 34      35                      Third Conspirator       Third Conspirator         NaN
# 35      36                        Third Gentleman         Third Gentleman         NaN
# 36      37                             Third Goth              Third Goth         NaN
# 37      38                         Third Murderer          Third Murderer         NaN
# 38      39                         Third Musician          Third Musician         NaN
# 39      40                      Third Serving-Man       Third Serving-Man         NaN
# 40      41                         Third Watchman          Third Watchman         NaN
# 41      42                            Third Witch             Third Witch         NaN
# 42      43                       Fourth Gentleman        Fourth Gentleman         NaN
# 44      45                                  Abbot                   Abbot         NaN
# 45      46                       Lord Abergavenny             ABERGAVENNY         NaN
# 52      53                                 Aedile                  Aedile         NaN
# 59      60                   Sir Andrew Aguecheek              SIR ANDREW         NaN
# 67      68                                    All                     All         NaN
# 68      69                                    All                     All         NaN
# 69      70                           All Citizens            All Citizens         NaN
# 70      71                       All Conspirators        All Conspirators         NaN
# 71      72                                    All                     All         NaN
# 72      73                                    All                     All         NaN
# 73      74                          All the Goths           All the Goths         NaN
# 74      75                                    All                     All         NaN
# 75      76                                    All                     All         NaN
# 76      77                                    All                     All         NaN
# 77      78                                    All                     All         NaN
# 78      79                                    All                     All         NaN
# 79      80                                    All                     All         NaN
# 80      81                                    All                     All         NaN
# 81      82                                    All                     All         NaN
# 82      83                             All Ladies              All Ladies         NaN
# 83      84                              All Lords               All Lords         NaN
# 84      85                              All Lords               All Lords         NaN
# 85      86                                    All                     ALL         NaN
# 86      87                                    All                     All         NaN
# 87      88                                    All                     All         NaN
# 88      89                                    All                     All         NaN
# 89      90                                    All                     All         NaN
# 90      91                         All The People          All The People         NaN
# 91      92                                    All                     All         NaN
# 92      93                                    All                     All         NaN
# 93      94                           All Servants            All Servants         NaN
# 94      95                                    All                     All         NaN
# 95      96                                    All                     All         NaN
# 96      97                                    All                     All         NaN
# 97      98                                    All                     ALL         NaN
# 99     100                             Ambassador              Ambassador         NaN
# 111    112                  Daughter of Antiochus                Daughter         NaN
# 121    122                             Apothecary              Apothecary         NaN
# 127    128                             Attendants              Attendants         NaN
# 128    129                              Attendant               Attendant         NaN
# 129    130                              Attendant               Attendant         NaN
# 130    131                              Attendant               ATTENDANT         NaN
# 139    140                               Banditti                Banditti         NaN
# 142    143                          Lord Bardolph           LORD BARDOLPH         NaN
# 143    144                               Bardolph                BARDOLPH         NaN
# 149    150                     Bastard of Orleans      BASTARD OF ORLEANS         NaN
# 151    152                                   Bawd                    Bawd         NaN
# 152    153                                 Beadle                  Beadle         NaN
# 153    154                           First Beadle            FIRST BEADLE         NaN
# 154    155                          Second Beadle           SECOND BEADLE         NaN
# 165    166                                 Bianca                  BIANCA         NaN
# 167    168                             Lord Bigot                   BIGOT         NaN
# 168    169                              Biondello               BIONDELLO         NaN
# 170    171                     Bishop of Carlisle      BISHOP OF CARLISLE         NaN
# 171    172                         Bishop Lincoln                 LINCOLN         NaN
# 173    174                                  Blunt                   BLUNT         NaN
# 174    175                                  Blunt                   Blunt         NaN
# 175    176                              Boatswain               Boatswain         NaN
# 179    180                                   Both                    Both         NaN
# 180    181                          Both Citizens           Both Citizens         NaN
# 181    182                                   Both                    Both         NaN
# 182    183                                   Both                    Both         NaN
# 183    184                                   Both                    Both         NaN
# 184    185                                   Both                    Both         NaN
# 185    186                                   Both                    Both         NaN
# 186    187                                   Both                    Both         NaN
# 187    188                          Both Tribunes           Both Tribunes         NaN
# 190    191                        Duke of Bourbon                 BOURBON         NaN
# 192    193                                    Boy                     Boy         NaN
# 194    195                                    Boy                     Boy         NaN
# 198    199                                Brandon                 BRANDON         NaN
# 199    200                               Brothers                BROTHERS         NaN
# 209    210                      Earl of Cambridge               CAMBRIDGE         NaN
# 211    212                      Cardinal Campeius       CARDINAL CAMPEIUS         NaN
# 213    214               Archbishop of Canterbury              CANTERBURY         NaN
# 215    216                                Captain                 Captain         NaN
# 216    217                                Captain                 Captain         NaN
# 217    218                                Captain                 Captain         NaN
# 218    219                                Captain                    Capt         NaN
# 219    220                                Captain                 Captain         NaN
# 220    221                                Captain                 Captain         NaN
# 226    227                                Carrier                 Carrier         NaN
# 235    236                            Chamberlain             Chamberlain         NaN
# 240    241                     Lord Chief Justice           CHIEF JUSTICE         NaN
# 241    242                               Children                Children         NaN
# 243    244                                 Chorus                  Chorus         NaN
# 244    245                                 Chorus                  Chorus         NaN
# 245    246                                 Chorus                  Chorus         NaN
# 246    247                                 Chorus                  Chorus         NaN
# 250    251                         Cinna the Poet          CINNA THE POET         NaN
# 251    252                                Citizen                 Citizen         NaN
# 252    253                               Citizens                Citizens         NaN
# 253    254                               Citizens                Citizens         NaN
# 254    255                               Citizens                Citizens         NaN
# 262    263                       Clerk of Chatham                   Clerk         NaN
# 263    264                                  Clerk                   Clerk         NaN
# 266    267                            First Clown                   Clown         NaN
# 267    268                           Second Clown                   Other         NaN
# 268    269                                  Clown                   Clown         NaN
# 271    272                                  Clown                   Clown         NaN
# 274    275                      Sir John Colville                COLVILLE         NaN
# 276    277                                Commons                 Commons         NaN
# 278    279                    Constable of France               Constable         NaN
# 286    287                   Countess of Auvergne    COUNTESS OF AUVERGNE         NaN
# 289    290                              Courtezan               Courtezan         NaN
# 292    293                                  Crier                   Crier         NaN
# 294    295                                  Cupid                   Cupid         NaN
# 297    298                                 Curtis                  CURTIS         NaN
# 300    301                      Lewis the Dauphin                 DAUPHIN         NaN
# 308    309                      Sir Anthony Denny                   DENNY         NaN
# 312    313                                  Diana                   DIANA         NaN
# 320    321                                 Doctor                    Doct         NaN
# 321    322                                 Doctor                  Doctor         NaN
# 330    331                          Second Drawer           SECOND DRAWER         NaN
# 331    332                           Third Drawer            THIRD DRAWER         NaN
# 334    335                  Duchess of Gloucester                 DUCHESS         NaN
# 335    336                        Duchess of York         DUCHESS OF YORK         NaN
# 338    339                         Duke of Albany                     Alb         NaN
# 339    340                        Duke of Alencon                 ALENCON         NaN
# 341    342                     Duke of Buckingham              BUCKINGHAM         NaN
# 342    343                     Duke of Buckingham              BUCKINGHAM         NaN
# 343    344                       Duke of Burgundy                     Bur         NaN
# 344    345                       Duke of Burgundy                BURGUNDY         NaN
# 345    346                       Duke of Cornwall                    Corn         NaN
# 346    347                       Duke of Florence                    DUKE         NaN
# 348    349                        Duke of Norfolk                 NORFOLK         NaN
# 349    350                        Duke of Norfolk                 NORFOLK         NaN
# 350    351                        Duke of Suffolk                 SUFFOLK         NaN
# 351    352                         Duke of Surrey          DUKE OF SURREY         NaN
# 352    353                         Duke of Venice          DUKE OF VENICE         NaN
# 356    357                        Earl of Douglas         Earl of Douglas         NaN
# 357    358                           Earl of Kent                    Kent         NaN
# 358    359                 Earl of Northumberland          NORTHUMBERLAND         NaN
# 359    360                 Earl of Northumberland          NORTHUMBERLAND         NaN
# 360    361                            Earl Oxford                  OXFORD         NaN
# 362    363                        Earl of Suffolk                 SUFFOLK         NaN
# 363    364                         Earl of Surrey                  SURREY         NaN
# 365    366                   Earl of Westmoreland            WESTMORELAND         NaN
# 367    368                Edmond, Earl of Rutland                 RUTLAND         NaN
# 371    372           King Edward IV (Plantagenet)                  EDWARD         NaN
# 374    375                               Egyptian                Egyptian         NaN
# 377    378                          Bishop of Ely                     ELY         NaN
# 380    381                         English Herald          English Herald         NaN
# 382    383                   Sir Thomas Erpingham               ERPINGHAM         NaN
# 389    390                    Sir Pierce of Exton                   EXTON         NaN
# 391    392                                  Fairy                   Fairy         NaN
# 401    402                          Fifth Citizen           Fifth Citizen         NaN
# 402    403                       First Ambassador        First Ambassador         NaN
# 403    404                        First Attendant         First Attendant         NaN
# 404    405                           First Bandit            First Bandit         NaN
# 406    407                  First British Captain           First Captain         NaN
# 407    408                          First Carrier           First Carrier         NaN
# 408    409                          First Citizen           First Citizen         NaN
# 409    410                          First Citizen           First Citizen         NaN
# 410    411                          First Citizen           First Citizen         NaN
# 411    412                          First Citizen           First Citizen         NaN
# 412    413                          First Citizen           First Citizen         NaN
# 413    414                         First Commoner          First Commoner         NaN
# 414    415                      First Executioner       First Executioner         NaN
# 415    416                        First Fisherman         First Fisherman         NaN
# 416    417                           First Gaoler            First Gaoler         NaN
# 417    418                           First Gaoler            First Gaoler         NaN
# 418    419                        First Gentleman         First Gentleman         NaN
# 419    420                        First Gentleman         First Gentleman         NaN
# 421    422                        First Gentleman         First Gentleman         NaN
# 422    423                        First Gentleman         First Gentleman         NaN
# 423    424                        First Gentleman         First Gentleman         NaN
# 424    425                        First Gentleman         First Gentleman         NaN
# 425    426                            First Guard             First Guard         NaN
# 426    427                           First Herald            First Herald         NaN
# 427    428                           First Keeper            First Keeper         NaN
# 428    429                           First Knight            First Knight         NaN
# 429    430                             First Lady              First Lady         NaN
# 430    431                             First Lady              First Lady         NaN
# 431    432                             First Lady              First Lady         NaN
# 432    433                             First Lord              First Lord         NaN
# 433    434                             First Lord              First Lord         NaN
# 434    435                             First Lord              FIRST LORD         NaN
# 436    437                             First Lord              First Lord         NaN
# 437    438                             First Lord              First Lord         NaN
# 438    439                             First Lord              First Lord         NaN
# 439    440                             First Lord              First Lord         NaN
# 441    442                        First Messenger         First Messenger         NaN
# 442    443                         First Murderer          First Murderer         NaN
# 443    444                         First Murderer          First Murderer         NaN
# 444    445                        First Neighbour         First Neighbour         NaN
# 445    446                          First Officer           First Officer         NaN
# 446    447                          First Officer           First Officer         NaN
# 447    448                          First Officer           First Officer         NaN
# 448    449                           First Outlaw            First Outlaw         NaN
# 449    450                       First Petitioner        First Petitioner         NaN
# 450    451                           First Pirate            First Pirate         NaN
# 451    452                        First 'Prentice         First 'Prentice         NaN
# 452    453                            First Roman             First Roman         NaN
# 453    454                           First Sailor            First Sailor         NaN
# 455    456                          First Senator           First Senator         NaN
# 456    457                          First Senator           First Senator         NaN
# 457    458                         First Sentinel          First Sentinel         NaN
# 458    459                          First Servant           First Servant         NaN
# 459    460                          First Servant           First Servant         NaN
# 460    461                          First Servant           First Servant         NaN
# 461    462                          First Servant           First Servant         NaN
# 462    463                          First Servant           First Servant         NaN
# 463    464                       First Serviceman        First Serviceman         NaN
# 464    465                       First Servingman        First Servingman         NaN
# 465    466                          First Soldier           First Soldier         NaN
# 466    467                          First Soldier           First Soldier         NaN
# 467    468                          First Soldier           First Soldier         NaN
# 468    469                          First Soldier           First Soldier         NaN
# 469    470                         First Stranger          First Stranger         NaN
# 470    471                        First Traveller         First Traveller         NaN
# 471    472                          First Tribune           First Tribune         NaN
# 472    473                           First Warder            First Warder         NaN
# 473    474                         First Watchman          First Watchman         NaN
# 474    475                              Flaminius               Flaminius         NaN
# 479    480                               Fluellen                FLUELLEN         NaN
# 481    482                                   Fool                    Fool         NaN
# 482    483                                   Fool                    Fool         NaN
# 484    485                               Forester                Forester         NaN
# 486    487                         Fourth Citizen          Fourth Citizen         NaN
# 487    488                         Fourth Citizen          Fourth Citizen         NaN
# 488    489                            Fourth Lord             Fourth Lord         NaN
# 489    490                            Fourth Lord             Fourth Lord         NaN
# 490    491                       Fourth Messenger        Fourth Messenger         NaN
# 491    492                         Fourth Soldier          Fourth Soldier         NaN
# 497    498                          French Herald           French Herald         NaN
# 500    501                         French Soldier          French Soldier         NaN
# 501    502                          Friar Francis           FRIAR FRANCIS         NaN
# 504    505                            Friar Peter             FRIAR PETER         NaN
# 505    506                           Friar Thomas            FRIAR THOMAS         NaN
# 507    508                               Gadshill                Gadshill         NaN
# 509    510                                 Gaoler                  Gaoler         NaN
# 510    511                                 Gaoler                  Gaoler         NaN
# 511    512                               Gardener                Gardener         NaN
# 516    517                              Gentleman               Gentleman         NaN
# 517    518                              Gentleman               Gentleman         NaN
# 518    519                              Gentleman                    Gent         NaN
# 519    520                              Gentleman               Gentleman         NaN
# 520    521                              Gentleman               Gentleman         NaN
# 521    522                              Gentleman               Gentleman         NaN
# 522    523                              Gentlemen               GENTLEMEN         NaN
# 524    525                            Gentlewoman             Gentlewoman         NaN
# 525    526                              Gentlemen               Gentlemen         NaN
# 526    527  George Plantagenet (Duke of Clarence)                  GEORGE         NaN
# 528    529                                   Girl                    Girl         NaN
# 529    530                              Glendower               GLENDOWER         NaN
# 531    532                    Earl of Glouchester                    Glou         NaN
# 534    535                   Governor of Harfleur                GOVERNOR         NaN
# 535    536                                  Gower                   GOWER         NaN
# 542    543                                 Gremio                  GREMIO         NaN
# 543    544                        Sir Thomas Grey                    GREY         NaN
# 545    546                                  Groom                   Groom         NaN
# 546    547                            First Groom             FIRST GROOM         NaN
# 547    548                           Second Groom            SECOND GROOM         NaN
# 548    549                            Third Groom             THIRD GROOM         NaN
# 550    551                                  Guard                   Guard         NaN
# 553    554                    Sir Henry Guildford               GUILDFORD         NaN
# 555    556                            Haberdasher             HABERDASHER         NaN
# 559    560                                Players                     NaN         NaN
# 560    561                                 Priest                  Priest         NaN
# 561    562                               Harcourt                HARCOURT         NaN
# 562    563                          Lord Hastings                HASTINGS         NaN
# 563    564                                 Hecate                  HECATE         NaN
# 573    574                               Henry VI           KING HENRY VI         NaN
# 575    576                             Henry VIII         KING HENRY VIII         NaN
# 577    578                                 Herald                  Herald         NaN
# 578    579                                 Herald                  Herald         NaN
# 579    580                                 Herald                  Herald         NaN
# 580    581                                 Herald                     Her         NaN
# 581    582                                 Herald                  Herald         NaN
# 588    589                              Hortensio               HORTENSIO         NaN
# 589    590                             Hortensius              HORTENSIUS         NaN
# 591    592                                Hostess                 HOSTESS         NaN
# 592    593                  Hotspur (Henry Percy)                 HOTSPUR         NaN
# 593    594                        Hubert de Burgh                  HUBERT         NaN
# 594    595                               Huntsman                Huntsman         NaN
# 595    596                         First Huntsman          FIRST HUNTSMAN         NaN
# 596    597                        Second Huntsman         SECOND HUNTSMAN         NaN
# 597    598                                  Hymen                   HYMEN         NaN
# 603    604                           Queen Isabel            QUEEN ISABEL         NaN
# 606    607                                   Jamy                    JAMY         NaN
# 611    612                               Jeweller                Jeweller         NaN
# 626    627                                Jupiter                 Jupiter         NaN
# 627    628                                Justice                 Justice         NaN
# 631    632                                 Keeper                  Keeper         NaN
# 632    633                                 Keeper                  Keeper         NaN
# 633    634                           Earl of Kent                     NaN         NaN
# 634    635                         King of France                    KING         NaN
# 635    636                         King of France                  France         NaN
# 638    639                                 Knight                  Knight         NaN
# 639    640                                Knights                 Knights         NaN
# 642    643                                   Lady                    Lady         NaN
# 645    646                           Lady Macbeth            LADY MACBETH         NaN
# 646    647                           Lady Macduff            LADY MACDUFF         NaN
# 648    649                    Lady Northumberland     LADY NORTHUMBERLAND         NaN
# 649    650                             Lady Percy              LADY PERCY         NaN
# 656    657                                Lavinia                 LAVINIA         NaN
# 657    658                                 Lawyer                  Lawyer         NaN
# 660    661                                 Legate                  Legate         NaN
# 675    676                                   Lord                    LORD         NaN
# 676    677                          Lord Berkeley           LORD BERKELEY         NaN
# 677    678                       Lord Chamberlain             Chamberlain         NaN
# 678    679                        Lord Chancellor              Chancellor         NaN
# 679    680                          Lord Clifford                CLIFFORD         NaN
# 680    681                                   Lord                    Lord         NaN
# 681    682                         Lord Fitzwater          LORD FITZWATER         NaN
# 683    684                                   Lord                    Lord         NaN
# 684    685                          Lord Hastings                HASTINGS         NaN
# 685    686                                   Lord                    Lord         NaN
# 686    687                             Lord Lovel                   LOVEL         NaN
# 687    688                                   Lord                    Lord         NaN
# 688    689                                   Lord                    Lord         NaN
# 689    690                           Lord Marshal            LORD MARSHAL         NaN
# 690    691                                   Lord                    Lord         NaN
# 692    693                             Lord Sands                   SANDS         NaN
# 693    694                               Lord Say                     SAY         NaN
# 694    695                            Lord Scales                  SCALES         NaN
# 695    696                            Lord Scroop                  SCROOP         NaN
# 696    697                                  Lords                   Lords         NaN
# 697    698                                  Lords                   Lords         NaN
# 698    699                                  Lords                   LORDS         NaN
# 699    700                          Lord Stafford                STAFFORD         NaN
# 700    701                                  Lords                   Lords         NaN
# 701    702                                   Lord                    LORD         NaN
# 702    703                        Lord Willoughby         LORD WILLOUGHBY         NaN
# 703    704                                   Lord                    Lord         NaN
# 705    706                      Sir Thomas Lovell                  LOVELL         NaN
# 710    711                               Lucianus                     Luc         NaN
# 713    714                      Lucilius' Servant       Lucilius' Servant         NaN
# 725    726                              Macmorris               MACMORRIS         NaN
# 740    741                                Mariana                 MARIANA         NaN
# 742    743                               Mariners                Mariners         NaN
# 743    744                                Mariner                 Mariner         NaN
# 744    745                   Marquess of Montague                MONTAGUE         NaN
# 746    747                                Marshal                 Marshal         NaN
# 750    751                                 Master                  Master         NaN
# 753    754                          Matthew Goffe           MATTHEW GOFFE         NaN
# 754    755                 Mayor of Saint Alban's                   Mayor         NaN
# 755    756                   Lord Mayor of London                   Mayor         NaN
# 756    757                          Mayor of York                   Mayor         NaN
# 765    766                               Merchant                Merchant         NaN
# 768    769                              Messenger               Messenger         NaN
# 769    770                              Messenger               Messenger         NaN
# 770    771                              Messenger               Messenger         NaN
# 771    772                              Messenger               Messenger         NaN
# 772    773                              Messenger               MESSENGER         NaN
# 773    774                              Messenger               Messenger         NaN
# 774    775                              Messenger               Messenger         NaN
# 775    776                              Messenger               Messenger         NaN
# 776    777                              Messenger               Messenger         NaN
# 777    778                              Messenger               Messenger         NaN
# 778    779                              Messenger                    Mess         NaN
# 779    780                              Messenger               Messenger         NaN
# 780    781                              Messenger               Messenger         NaN
# 781    782                              Messenger                    Mess         NaN
# 782    783                              Messenger               Messenger         NaN
# 783    784                              Messenger               Messenger         NaN
# 784    785                              Messenger               Messenger         NaN
# 785    786                              Messenger               Messenger         NaN
# 786    787                              Messenger               Messenger         NaN
# 787    788                              Messenger               Messenger         NaN
# 788    789                              Messenger               Messenger         NaN
# 789    790                              Messenger               Messenger         NaN
# 790    791                              Messenger               MESSENGER         NaN
# 794    795                          Mistress Ford           MISTRESS FORD         NaN
# 796    797                          Mistress Page           MISTRESS PAGE         NaN
# 807    808                           Lord Mowbray                 MOWBRAY         NaN
# 815    816                               Nobleman                Nobleman         NaN
# 816    817                      Norwegian Captain                    Capt         NaN
# 818    819                                  Nurse                   Nurse         NaN
# 824    825                                Officer                 Officer         NaN
# 825    826                                Officer                 Officer         NaN
# 826    827                                Officer                 Officer         NaN
# 827    828                                Officer                 Officer         NaN
# 828    829                           Old Athenian            Old Athenian         NaN
# 832    833                                Old Man                 Old Man         NaN
# 835    836                                 Olivia                  OLIVIA         NaN
# 838    839                        Duke of Orleans                 ORLEANS         NaN
# 841    842                                 Ostler                  Ostler         NaN
# 844    845                                Outlaws                 Outlaws         NaN
# 845    846                             First Page              FIRST PAGE         NaN
# 846    847                            Second Page             SECOND PAGE         NaN
# 847    848                                   Page                    Page         NaN
# 851    852                                   Page                    Page         NaN
# 853    854                                   Page                    Page         NaN
# 854    855                                   Page                    PAGE         NaN
# 855    856                                Painter                 Painter         NaN
# 856    857                                 Pandar                  Pandar         NaN
# 863    864                              Patrician             A Patrician         NaN
# 867    868                                 Pedant                  PEDANT         NaN
# 869    870                       Earl of Pembroke                PEMBROKE         NaN
# 876    877                                   Peto                    PETO         NaN
# 890    891                                 Pistol                  PISTOL         NaN
# 891    892                                Players                 PLAYERS         NaN
# 892    893                                 Player                  PLAYER         NaN
# 894    895                                   Poet                    Poet         NaN
# 895    896                                   Poet                    Poet         NaN
# 896    897                           Edward Poins                   POINS         NaN
# 902    903                                 Porter                  PORTER         NaN
# 903    904                                 Porter                  Porter         NaN
# 905    906                                 Porter                  Porter         NaN
# 908    909                                   Post                    Post         NaN
# 909    910                                   Post                    Post         NaN
# 912    913                                 Priest                  Priest         NaN
# 913    914                                 Priest                  Priest         NaN
# 915    916                          Prince Edward           PRINCE EDWARD         NaN
# 920    921                                Princes                 Princes         NaN
# 921    922                     Princess of France                PRINCESS         NaN
# 925    926                                Provost                 Provost         NaN
# 929    930                             Pursuivant              Pursuivant         NaN
# 934    935                                  Queen                   QUEEN         NaN
# 946    947        Richard Plantagenet the Younger                 RICHARD         NaN
# 949    950                          Roman Captain                 Captain         NaN
# 950    951                                  Roman                   Roman         NaN
# 956    957                              Lord Ross               LORD ROSS         NaN
# 959    960                                 Sailor                  Sailor         NaN
# 960    961                                 Sailor                  Sailor         NaN
# 964    965                      Earl of Salisbury               SALISBURY         NaN
# 966    967                      Earl of Salisbury       EARL OF SALISBURY         NaN
# 970    971                                  Scout                   Scout         NaN
# 971    972                                 Scribe                  Scribe         NaN
# 972    973                              Scrivener               Scrivener         NaN
# 977    978                       Second Attendant        Second Attendant         NaN
# 978    979                          Second Bandit           Second Bandit         NaN
# 980    981                 Second British Captain          Second Captain         NaN
# 981    982                         Second Carrier          Second Carrier         NaN
# 982    983                         Second Citizen          Second Citizen         NaN
# 983    984                         Second Citizen          Second Citizen         NaN
# 984    985                         Second Citizen          Second Citizen         NaN
# 985    986                        Second Commoner         Second Commoner         NaN
# 986    987                       Second Fisherman        Second Fisherman         NaN
# 987    988                          Second Gaoler           Second Gaoler         NaN
# 988    989                       Second Gentleman        Second Gentleman         NaN
# 989    990                       Second Gentleman        Second Gentleman         NaN
# 991    992                       Second Gentleman        Second Gentleman         NaN
# 992    993                       Second Gentleman        Second Gentleman         NaN
# 993    994                       Second Gentleman        Second Gentleman         NaN
# 994    995                       Second Gentleman        Second Gentleman         NaN
# 995    996                           Second Guard            Second Guard         NaN
# 996    997                          Second Herald           Second Herald         NaN
# 997    998                          Second Keeper           Second Keeper         NaN
# 998    999                          Second Knight           Second Knight         NaN
# 999   1000                            Second Lady             Second Lady         NaN
# 1000  1001                            Second Lord             Second Lord         NaN
# 1001  1002                            Second Lord             Second Lord         NaN
# 1002  1003                            Second Lord             SECOND LORD         NaN
# 1004  1005                            Second Lord             Second Lord         NaN
# 1005  1006                            Second Lord             Second Lord         NaN
# 1007  1008                       Second Messenger        Second Messenger         NaN
# 1008  1009                       Second Messenger        Second Messenger         NaN
# 1009  1010                       Second Messenger        Second Messenger         NaN
# 1010  1011                       Second Messenger        Second Messenger         NaN
# 1011  1012                        Second Murderer         Second Murderer         NaN
# 1012  1013                        Second Murderer         Second Murderer         NaN
# 1013  1014                       Second Neighbour        Second Neighbour         NaN
# 1014  1015                         Second Officer          Second Officer         NaN
# 1015  1016                         Second Officer          Second Officer         NaN
# 1016  1017                         Second Officer          Second Officer         NaN
# 1017  1018                          Second Outlaw           Second Outlaw         NaN
# 1018  1019                      Second Petitioner       Second Petitioner         NaN
# 1019  1020                          Second Pirate           Second Pirate         NaN
# 1020  1021                       Second 'Prentice        Second 'Prentice         NaN
# 1021  1022                           Second Roman            Second Roman         NaN
# 1022  1023                          Second Sailor           Second Sailor         NaN
# 1024  1025                         Second Senator          Second Senator         NaN
# 1025  1026                         Second Senator          Second Senator         NaN
# 1026  1027                        Second Sentinel         Second Sentinel         NaN
# 1027  1028                         Second Servant          Second Servant         NaN
# 1028  1029                         Second Servant          Second Servant         NaN
# 1029  1030                         Second Servant          Second Servant         NaN
# 1030  1031                         Second Servant          Second Servant         NaN
# 1031  1032                      Second Serviceman       Second Serviceman         NaN
# 1032  1033                      Second Servingman       Second Servingman         NaN
# 1033  1034                         Second Soldier          Second Soldier         NaN
# 1034  1035                         Second Soldier          Second Soldier         NaN
# 1035  1036                         Second Soldier          Second Soldier         NaN
# 1036  1037                        Second Stranger         Second Stranger         NaN
# 1037  1038                          Second Warder           Second Warder         NaN
# 1038  1039                        Second Watchman         Second Watchman         NaN
# 1043  1044                                Senator                 Senator         NaN
# 1044  1045                              Sentinels               Sentinels         NaN
# 1045  1046                               Sergeant                Sergeant         NaN
# 1047  1048                               Sergeant                Sergeant         NaN
# 1049  1050                                Servant                 Servant         NaN
# 1050  1051                              Servant 1                   Serv1         NaN
# 1051  1052                          First Servant           FIRST SERVANT         NaN
# 1052  1053                              Servant 2                   Serv2         NaN
# 1053  1054                         Second Servant          SECOND SERVANT         NaN
# 1054  1055                              Servant 3                   Serv3         NaN
# 1055  1056                          Third Servant           THIRD SERVANT         NaN
# 1056  1057                                Servant                 Servant         NaN
# 1057  1058                                Servant                 Servant         NaN
# 1058  1059                                Servant                 Servant         NaN
# 1059  1060                                Servant                 SERVANT         NaN
# 1060  1061                                Servant                 Servant         NaN
# 1061  1062                                Servant                 Servant         NaN
# 1062  1063                                Servant                 Servant         NaN
# 1063  1064                                Servant                 Servant         NaN
# 1064  1065                                Servant                 Servant         NaN
# 1065  1066                                Servant                 Servant         NaN
# 1066  1067                                Servant                 Servant         NaN
# 1067  1068                                Servant                 Servant         NaN
# 1068  1069                                Servant                 Servant         NaN
# 1069  1070                                Servant                 Servant         NaN
# 1070  1071                                Servant                 Servant         NaN
# 1071  1072                                Servant                 Servant         NaN
# 1072  1073                               Servants                Servants         NaN
# 1073  1074                               Servants            ALL SERVANTS         NaN
# 1074  1075                                Servant                 Servant         NaN
# 1075  1076                                Servant                 SERVANT         NaN
# 1076  1077                                Servant                 Servant         NaN
# 1078  1079                            Serving-Men             Serving-Men         NaN
# 1079  1080                        Seventh Citizen         Seventh Citizen         NaN
# 1080  1081                       Several Citizens        Several Citizens         NaN
# 1081  1082                                 Sexton                  Sexton         NaN
# 1086  1087                                Sheriff                 Sheriff         NaN
# 1087  1088                                Sheriff                 Sheriff         NaN
# 1088  1089                   Sheriff of Wiltshire                 Sheriff         NaN
# 1101  1102                       Sir James Blount                  Blount         NaN
# 1102  1103                       Sir James Tyrrel                  TYRREL         NaN
# 1103  1104                      Sir John Fastolfe                FASTOLFE         NaN
# 1104  1105                    Sir John Montgomery              MONTGOMERY         NaN
# 1106  1107                    Sir John Somerville              SOMERVILLE         NaN
# 1107  1108                       Sir John Stanley                 STANLEY         NaN
# 1110  1111                   Sir Richard Ratcliff                RATCLIFF         NaN
# 1111  1112                  Sir Robert Brakenbury              BRAKENBURY         NaN
# 1112  1113                     Sir Stephen Scroop      SIR STEPHEN SCROOP         NaN
# 1113  1114                    Sir Thomas Gargrave                GARGRAVE         NaN
# 1114  1115                     Sir Thomas Vaughan                 VAUGHAN         NaN
# 1115  1116                     Sir Walter Herbert                 HERBERT         NaN
# 1116  1117                    Sir William Catesby                 CATESBY         NaN
# 1117  1118                 Sir  William Glansdale               GLANSDALE         NaN
# 1118  1119                       Sir William Lucy                    LUCY         NaN
# 1121  1122                          Sixth Citizen           Sixth Citizen         NaN
# 1128  1129                                Soldier                 Soldier         NaN
# 1129  1130                                Soldier                 Soldier         NaN
# 1130  1131                                Soldier                 Soldier         NaN
# 1131  1132                                Soldier                 Soldier         NaN
# 1132  1133                               Soldiers                Soldiers         NaN
# 1133  1134                                Soldier                 Soldier         NaN
# 1135  1136                            Some Others             Some Others         NaN
# 1137  1138                             Some Speak              Some Speak         NaN
# 1140  1141                             Soothsayer              Soothsayer         NaN
# 1141  1142                             Soothsayer              Soothsayer         NaN
# 1142  1143                             Soothsayer              Soothsayer         NaN
# 1144  1145                                 Spirit                  Spirit         NaN
# 1150  1151                         Earl of Surrey                     NaN         NaN
# 1152  1153                                 Tailor                  TAILOR         NaN
# 1153  1154         Lord Talbot/Earl of Shrewsbury             JOHN TALBOT         NaN
# 1154  1155                                 Tamora                  TAMORA         NaN
# 1156  1157                         Doll Tearsheet                    DOLL         NaN
# 1161  1162                                Thieves                 Thieves         NaN
# 1162  1163                           Third Bandit            Third Bandit         NaN
# 1163  1164                          Third Citizen           Third Citizen         NaN
# 1164  1165                          Third Citizen           Third Citizen         NaN
# 1165  1166                          Third Citizen           Third Citizen         NaN
# 1166  1167                        Third Fisherman         Third Fisherman         NaN
# 1167  1168                        Third Gentleman         Third Gentleman         NaN
# 1168  1169                        Third Gentleman         Third Gentleman         NaN
# 1169  1170                            Third Guard             Third Guard         NaN
# 1170  1171                           Third Knight            Third Knight         NaN
# 1171  1172                             Third Lord              Third Lord         NaN
# 1172  1173                             Third Lord              Third Lord         NaN
# 1173  1174                             Third Lord              Third Lord         NaN
# 1174  1175                             Third Lord              Third Lord         NaN
# 1175  1176                        Third Messenger         Third Messenger         NaN
# 1176  1177                        Third Neighbour         Third Neighbour         NaN
# 1177  1178                          Third Officer           Third Officer         NaN
# 1178  1179                           Third Outlaw            Third Outlaw         NaN
# 1179  1180                           Third Pirate            Third Pirate         NaN
# 1180  1181                            Third Roman             Third Roman         NaN
# 1181  1182                          Third Senator           Third Senator         NaN
# 1182  1183                          Third Servant           Third Servant         NaN
# 1183  1184                       Third Serviceman        Third Serviceman         NaN
# 1184  1185                       Third Servingman        Third Servingman         NaN
# 1185  1186                          Third Soldier           Third Soldier         NaN
# 1186  1187                          Third Soldier           Third Soldier         NaN
# 1187  1188                         Third Stranger          Third Stranger         NaN
# 1188  1189                         Third Watchman          Third Watchman         NaN
# 1197  1198                                  Timon                   TIMON         NaN
# 1203  1204                               Townsman                Townsman         NaN
# 1204  1205                                 Tranio                  TRANIO         NaN
# 1205  1206                             Travellers              Travellers         NaN
# 1209  1210                               Tribunes                Tribunes         NaN
# 1214  1215                       Tutor of Rutland                   Tutor         NaN
# 1216  1217                          Tyrian Sailor           Tyrian Sailor         NaN
# 1224  1225                                Varrius                 VARRIUS         NaN
# 1226  1227                  Varro's First Servant   Varro's First Servant         NaN
# 1227  1228                 Varro's Second Servant  Varro's Second Servant         NaN
# 1228  1229                      Sir Nicholas Vaux                    VAUX         NaN
# 1229  1230                                   Vaux                    VAUX         NaN
# 1236  1237                                Vintner                 Vintner         NaN
# 1237  1238                                  Viola                   VIOLA         NaN
# 1240  1241                                 Volsce                  Volsce         NaN
# 1244  1245                        Walter Whitmore                WHITMORE         NaN
# 1246  1247                        Earl of Warwick                 WARWICK         NaN
# 1247  1248                                  Watch                   Watch         NaN
# 1248  1249                               Watchman                Watchman         NaN
# 1249  1250                   Earl of Westmoreland            WESTMORELAND         NaN
# 1250  1251                                  Widow                   WIDOW         NaN
# 1252  1253                         Simpcox's Wife                    Wife         NaN
# 1257  1258                        Cardinal Wolsey         CARDINAL WOLSEY         NaN
# 1259  1260                      Earl of Worcester       EARL OF WORCESTER         NaN
# 1260  1261                     (stage directions)                     xxx         NaN
# 1262  1263                         Young Clifford          YOUNG CLIFFORD         NaN

# %%
 df_characters[df_characters['CharName'] == 'Poet']
# Out:
#       id CharName Abbrev                        Description
# 893  894     Poet   Poet  the voice of Shakespeare's poetry
# 894  895     Poet   Poet                                NaN
# 895  896     Poet   Poet                                NaN

# %%
characters_filtered = df_characters[df_characters['CharName'] == '(stage directions)']
print(characters_filtered.to_string())
# Out:
#         id            CharName Abbrev Description
# 1260  1261  (stage directions)    xxx         NaN

# %%
print(df_paragraphs[df_paragraphs["character_id"] == 854]["CleanText"].to_string())
# Out:
# 31003     to the fool  why  how now  captain  what do y...
# 31005    prithee  apemantus  read me the superscription...
# 31007                                                  no
# 31009    thou wast whelped a dog  and thou shalt famish...

# %%
df_paragraphs
# Out:
#            id  ParagraphNum  \
# 0      630863             3
# 1      630864             4
# 2      630865            19
# 3      630866            20
# 4      630867            21
# ...       ...           ...
# 35460  666323          3460
# 35461  666324          3467
# 35462  666325          3475
# 35463  666326          3483
# 35464  666327          3504
#
#                                                PlainText  character_id  \
# 0      [Enter DUKE ORSINO, CURIO, and other Lords; Mu...          1261
# 1      If music be the food of love, play on;\nGive m...           840
# 2                             Will you go hunt, my lord?           297
# 3                                           What, Curio?           840
# 4                                              The hart.           297
# ...                                                  ...           ...
# 35460  That she is living,\nWere it but told you, sho...           866
# 35461  You gods, look down\nAnd from your sacred vial...           584
# 35462  There's time enough for that;\nLest they desir...           866
# 35463  O, peace, Paulina!\nThou shouldst a husband ta...           667
# 35464                                           [Exeunt]          1261
#
#        chapter_id                                          CleanText  \
# 0           18704   enter duke orsino  curio  and other lords  mu...
# 1           18704  if music be the food of love  play on \ngive m...
# 2           18704                         will you go hunt  my lord
# 3           18704                                       what  curio
# 4           18704                                          the hart
# ...           ...                                                ...
# 35460       19648  that she is living \nwere it but told you  sho...
# 35461       19648  you gods  look down\nand from your sacred vial...
# 35462       19648  there s time enough for that \nlest they desir...
# 35463       19648  o  peace  paulina \nthou shouldst a husband ta...
# 35464       19648                                            exeunt
#
#                                                 WordList
# 0      [enter, duke, orsino, curio, and, other, lords...
# 1      [if, music, be, the, food, of, love, play, on,...
# 2                        [will, you, go, hunt, my, lord]
# 3                                          [what, curio]
# 4                                            [the, hart]
# ...                                                  ...
# 35460  [that, she, is, living, were, it, but, told, y...
# 35461  [you, gods, look, down, and, from, your, sacre...
# 35462  [there, s, time, enough, for, that, lest, they...
# 35463  [o, peace, paulina, thou, shouldst, a, husband...
# 35464                                           [exeunt]
#
# [35465 rows x 7 columns]
